# %%
import pandas as pd
import psutil
import os
import numpy as np
import sys
import faiss
import sys
import time 
import torch
import tracemalloc
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, matthews_corrcoef, homogeneity_completeness_v_measure
import seaborn as sns
import matplotlib.pyplot as plt

# %%
embedding_db = np.load("db_embedding.npy")
embedding_t = np.load("test_embedding.npy")
X_train = pd.read_csv("metadata_db.csv")
X_test = pd.read_csv("metadata_test.csv")

# %%
#embedding_db.shape
num_features = embedding_db.shape[1]
print(embedding_db.shape[0])
#crit = faiss.OneRecallAtRCriterion(embedding_t.shape[0], 1)
# Out:
# 165615

# %% [markdown]
# Parameter Sweep

# %%
import time
import faiss
import psutil
import os
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef, homogeneity_completeness_v_measure
import pandas as pd

use_gpu = False

if use_gpu:
    # if this fails, it means that the GPU version was not comp
    res = faiss.StandardGpuResources()
    dev_no = 0

# Test Different Indexing Methods: IndexFlatL2, IndexFlatL2 w/ PCAmatrix, IndexIVFFlat, etc.
index_key = ['Flat', 'PCA64,Flat', 'PCAR64,Flat', 'PCAW64,Flat', 'PCAWR64,Flat', 'IVF4096,Flat', 'PCA64,IVF4096,Flat', 'PCAR64,IVF4096,Flat', 'PCAW64,IVF4096,Flat', 'PCAWR64,IVF4096,Flat', 'IVF4096,PQ16', 'OPQ16,IVF4096,PQ16', 'OPQ32,IVF4096,PQ32', 'OPQ32,IVF4096,PQ16x4fsr']

# Initialize an empty DataFrame or load an existing one if available
results_file_path = 'results.csv'
if os.path.exists(results_file_path):
    result_df = pd.read_csv(results_file_path)
else:
    result_df = pd.DataFrame()

for key in index_key:
    #Sweep through indexing methods seen in index_key
    r = range(100, 1000, 100)
    start = time.time()
    tracemalloc.start()
    index = faiss.index_factory(num_features, key)
    nlist = 4096
    if use_gpu:
        # transfer to GPU (may be partial)
        index = faiss.index_cpu_to_gpu(res, dev_no, index)

    start_indexing = time.time()
    # Index Database Embedding
    index.train(embedding_db)
    index.add(embedding_db)
    elapsed_indexing = time.time() - start_indexing
    _, peak_i = tracemalloc.get_traced_memory()
    print(f'Time Indexing: {elapsed_indexing}')
    print('Memory Indexing % used:', peak_i)
    print('CPU Indexing % used:', psutil.cpu_percent())
    tracemalloc.stop()
    for i in r:
        #Test different values of nprobe to see their effects on the search process for each index.
        index.nprobe = i
        start_searching = time.time()
        # Search using Test Embedding
        tracemalloc.start()
        D_p, I_p = index.search(embedding_t, 1)
        elapsed_searching = time.time() - start_searching
        _, peak_s = tracemalloc.get_traced_memory()
        print(f'Time Searching: {elapsed_searching}')
        print('Memory Searching % used:', peak_s)
        print('CPU Searching % used:', psutil.cpu_percent())
        tracemalloc.stop()
        # Assuming each test embedding corresponds to a single label in the training data
        predicted_label = X_train.iloc[I_p.reshape(-1)]["gene"]

        # Calculate accuracy
        accuracy = accuracy_score(X_test["gene"], predicted_label)
        print(f'Accuracy: {accuracy}')
    
    
        # Calculate confusion matrix
        conf_matrix = confusion_matrix(X_test["gene"], predicted_label)

        # Calculate MCC, sensitivity, and specificity
        mcc = matthews_corrcoef(X_test["gene"], predicted_label)
        sensitivity = conf_matrix[1, 1] / (conf_matrix[1, 1] + conf_matrix[1, 0])
        specificity = conf_matrix[0, 0] / (conf_matrix[0, 0] + conf_matrix[0, 1])

        print(f'MCC: {mcc}')
        print(f'Sensitivity: {sensitivity}')
        print(f'Specificity: {specificity}')

        start_training_kmeans = time.time()
        tracemalloc.start()
        # Use Faiss K-Means algorithm to cluster database embeddings
        ncentroids = 1024
        niter = 60
        verbose = True
        kmeans = faiss.Kmeans(num_features, ncentroids, niter=niter, verbose=verbose)
        kmeans.train(embedding_db)
        elapsed_training_kmeans = time.time() - start_training_kmeans
        _, peak_t = tracemalloc.get_traced_memory()
        print(f'Time training Kmeans: {elapsed_training_kmeans}')
        print('Memory training Kmeans % used:', peak_t)
        print('CPU training Kmeans % used:', psutil.cpu_percent())
        tracemalloc.stop()
    
        start_searching_kmeans = time.time()
        tracemalloc.start()
        D, I = kmeans.index.search(embedding_t, 1)
        elapsed_searching_kmeans = time.time() - start_searching_kmeans
        _, peak_ks = tracemalloc.get_traced_memory()
        print(f'Time searching Kmeans: {elapsed_searching_kmeans}')
        print('Memory searching Kmeans % used:', peak_ks)
        print('CPU searching Kmeans % used:', psutil.cpu_percent())
        tracemalloc.stop()

        predicted_label_cluster_phylum = X_train.iloc[I.reshape(-1)]["phylum"]
        h_phylum, c_phylum, v_phylum = homogeneity_completeness_v_measure(X_test["phylum"], predicted_label_cluster_phylum)  # Verify

        print(f'Homogeneity Phylum: {h_phylum}')
        print(f'Completeness Phylum: {c_phylum}')
        print(f'V-Measure Phylum: {v_phylum}')
        print()

        predicted_label_cluster_genus = X_train.iloc[I.reshape(-1)]["genus"]
        h_genus, c_genus, v_genus = homogeneity_completeness_v_measure(X_test["genus"], predicted_label_cluster_genus)  # Verify

        print(f'Homogeneity Genus: {h_genus}')
        print(f'Completeness Genus: {c_genus}')
        print(f'V-Measure Genus: {v_genus}')
        print()

        print(index.ntotal)

        # Save results to DataFrame
        result_dict = {
            'Index': key,
            'Time Indexing': elapsed_indexing,
            'Time Searching': elapsed_searching,
            'Accuracy Gene': accuracy,
            'MCC Gene': mcc,
            'Sensitivity Gene': sensitivity,
            'Specificity Gene': specificity,
            'Time Training Kmeans': elapsed_training_kmeans,
            'Time Searching Kmeans': elapsed_searching_kmeans,
            'Homogeneity Phylum': h_phylum,
            'Completeness Phylum': c_phylum,
            'V-Measure Phylum': v_phylum,
            'Homogeneity Genus': h_genus,
            'Completeness Genus': c_genus,
            'V-Measure Genus': v_genus
        }

    # Append results to the DataFrame
        result_df = result_df.append(result_dict, ignore_index=True)

# Save the updated DataFrame to a CSV file
result_df.to_csv(results_file_path, index=False)
# Out:
# Time Indexing: 0.8508861064910889
# Memory Indexing % used: 1358271585
# CPU Indexing % used: 6.3
# Time Searching: 34.723170042037964
# Memory Searching % used: 58713096
# CPU Searching % used: 99.3
# Accuracy: 0.3534652076318743
# MCC: 0.34044968473423176
# Sensitivity: 0.9285714285714286
# Specificity: 0.937007874015748
# Time training Kmeans: 163.42626309394836
# Memory training Kmeans % used: 682721904
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.2752339839935303
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 81.8
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching:
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 38.994608640670776
# Memory Searching % used: 58711963
# CPU Searching % used: 99.5
# Accuracy: 0.3534652076318743
# MCC: 0.34044968473423176
# Sensitivity: 0.9285714285714286
# Specificity: 0.937007874015748
# Time training Kmeans: 173.63918662071228
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.28784799575805664
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 81.3
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 36.3061089515686
# Memory Searching % used: 58713370
# CPU Searching % used: 99.0
# Accuracy: 0.3534652076318743
# MCC: 0.34044968473423176
# Sensitivity: 0.9285714285714286
# Specificity: 0.937007874015748
# Time training Kmeans: 167.5418291091919
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.2932553291320801
# Memory searching Kmeans % used: 58713116
# CPU searching Kmeans % used: 80.9
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Indexing: 8.11118221282959
# Memory Indexing % used: 678508593
# CPU Indexing % used: 21.5
# Time Searching: 8.354577779769897
# Memory Searching % used: 58713094
# CPU Searching % used: 96.3
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 171.6350109577179
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.28470897674560547
# Memory searching Kmeans % used: 58713116
# CPU searching Kmeans % used: 89.5
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.376224517822266
# Memory Searching % used: 58711963
# CPU Searching % used: 95.6
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 170.50068402290344
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.3002593517303467
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 83.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 7.735369682312012
# Memory Searching % used: 58711963
# CPU Searching % used: 95.0
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 169.90283465385437
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 99.0
# Time searching Kmeans: 0.39034295082092285
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 82.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 7.866443634033203
# Memory Searching % used: 58564088
# CPU Searching % used: 95.0
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 169.6419816017151
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.2701752185821533
# Memory searching Kmeans % used: 58713116
# CPU searching Kmeans % used: 79.3
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 7.82536506652832
# Memory Searching % used: 58711963
# CPU Searching % used: 95.9
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 168.36344981193542
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.3803257942199707
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 86.8
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 7.998988389968872
# Memory Searching % used: 58711963
# CPU Searching % used: 96.1
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 168.43544363975525
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.2591876983642578
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 85.4
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.376252174377441
# Memory Searching % used: 58711963
# CPU Searching % used: 96.1
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 169.09521222114563
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.2601814270019531
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 83.5
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.264638662338257
# Memory Searching % used: 58711963
# CPU Searching % used: 95.4
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 169.59359765052795
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.28022003173828125
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 80.5
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.276049613952637
# Memory Searching % used: 58711963
# CPU Searching % used: 95.8
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 168.18275380134583
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.26012396812438965
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 79.4
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Indexing: 8.264853477478027
# Memory Indexing % used: 678508594
# CPU Indexing % used: 23.7
# Time Searching: 8.579644918441772
# Memory Searching % used: 58713095
# CPU Searching % used: 97.7
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 175.48856830596924
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.3776724338531494
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 88.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.327749490737915
# Memory Searching % used: 58564088
# CPU Searching % used: 96.4
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 164.29757618904114
# Memory training Kmeans % used: 682718298
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.2965106964111328
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 85.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.333590507507324
# Memory Searching % used: 58711963
# CPU Searching % used: 96.9
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 168.40799689292908
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.27010536193847656
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 82.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.304813861846924
# Memory Searching % used: 58711963
# CPU Searching % used: 96.0
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 171.35338377952576
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.37003207206726074
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 82.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.236021757125854
# Memory Searching % used: 58711671
# CPU Searching % used: 95.2
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 168.32329559326172
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.32017993927001953
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 77.3
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.014175415039062
# Memory Searching % used: 58711963
# CPU Searching % used: 94.8
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 171.6521430015564
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.2701401710510254
# Memory searching Kmeans % used: 58713116
# CPU searching Kmeans % used: 81.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 7.865522146224976
# Memory Searching % used: 58713369
# CPU Searching % used: 95.1
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 171.153404712677
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.27012133598327637
# Memory searching Kmeans % used: 58713115
# CPU searching Kmeans % used: 84.0
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.2940673828125
# Memory Searching % used: 58711963
# CPU Searching % used: 96.3
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 168.82280945777893
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.2586939334869385
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 81.9
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.67604660987854
# Memory Searching % used: 58713369
# CPU Searching % used: 96.5
# Accuracy: 0.3094837261503928
# MCC: 0.29549128782716405
# Sensitivity: 0.9041095890410958
# Specificity: 0.9245283018867925
# Time training Kmeans: 169.23409128189087
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.3102409839630127
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 85.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Indexing: 8.756749629974365
# Memory Indexing % used: 678508593
# CPU Indexing % used: 24.0
# Time Searching: 8.316173076629639
# Memory Searching % used: 58713095
# CPU Searching % used: 97.6
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 169.27394270896912
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.27010607719421387
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 85.5
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.284602642059326
# Memory Searching % used: 58713370
# CPU Searching % used: 95.2
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 173.26421356201172
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.30019402503967285
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 81.7
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.326032638549805
# Memory Searching % used: 58711963
# CPU Searching % used: 95.2
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 170.97853326797485
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.39738011360168457
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 86.9
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.24782109260559
# Memory Searching % used: 58711963
# CPU Searching % used: 95.7
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 170.22417545318604
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.2602050304412842
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 78.5
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 7.876004457473755
# Memory Searching % used: 58713369
# CPU Searching % used: 96.0
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 167.7733085155487
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.6
# Time searching Kmeans: 0.2802255153656006
# Memory searching Kmeans % used: 58713116
# CPU searching Kmeans % used: 82.3
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.236033201217651
# Memory Searching % used: 58713369
# CPU Searching % used: 97.3
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 168.44074130058289
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.6
# Time searching Kmeans: 0.2700841426849365
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 78.0
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.005467176437378
# Memory Searching % used: 58711963
# CPU Searching % used: 95.1
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 169.79186701774597
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.27015137672424316
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 79.3
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.40561294555664
# Memory Searching % used: 58711963
# CPU Searching % used: 95.9
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 170.28710508346558
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.2602667808532715
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 78.8
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.307141065597534
# Memory Searching % used: 58711963
# CPU Searching % used: 95.8
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 169.88733220100403
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.3101389408111572
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 87.6
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Indexing: 8.1251859664917
# Memory Indexing % used: 678508593
# CPU Indexing % used: 23.6
# Time Searching: 8.284531116485596
# Memory Searching % used: 58713093
# CPU Searching % used: 96.8
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 171.76723957061768
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.28020763397216797
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 80.3
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 9.01731252670288
# Memory Searching % used: 58713088
# CPU Searching % used: 97.8
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 170.28863263130188
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.30019259452819824
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 87.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.064291954040527
# Memory Searching % used: 58711963
# CPU Searching % used: 95.0
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 173.92949962615967
# Memory training Kmeans % used: 682718360
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.27019309997558594
# Memory searching Kmeans % used: 58713117
# CPU searching Kmeans % used: 80.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.729527473449707
# Memory Searching % used: 58711963
# CPU Searching % used: 97.2
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 170.22707176208496
# Memory training Kmeans % used: 682718556
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.2801845073699951
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 79.6
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.646878004074097
# Memory Searching % used: 58711991
# CPU Searching % used: 96.4
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 172.22623085975647
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.2902545928955078
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 80.1
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 7.989684104919434
# Memory Searching % used: 58713397
# CPU Searching % used: 96.2
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 172.37398147583008
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.2601001262664795
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 78.4
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 7.9362311363220215
# Memory Searching % used: 58711991
# CPU Searching % used: 96.4
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 171.4421145915985
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.300325870513916
# Memory searching Kmeans % used: 58713144
# CPU searching Kmeans % used: 83.5
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.471043825149536
# Memory Searching % used: 58711991
# CPU Searching % used: 95.3
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 169.98740577697754
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.27016592025756836
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 82.9
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 8.497657299041748
# Memory Searching % used: 58711991
# CPU Searching % used: 96.3
# Accuracy: 0.3624438832772166
# MCC: 0.3496682642720726
# Sensitivity: 0.9222222222222223
# Specificity: 0.9624060150375939
# Time training Kmeans: 171.38599252700806
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.3101489543914795
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 86.8
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Indexing: 123.25785446166992
# Memory Indexing % used: 678508621
# CPU Indexing % used: 96.7
# Time Searching: 12.142713069915771
# Memory Searching % used: 58713124
# CPU Searching % used: 95.9
# Accuracy: 0.35192199775533106
# MCC: 0.3388754123921413
# Sensitivity: 0.927710843373494
# Specificity: 0.937007874015748
# Time training Kmeans: 171.60209155082703
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.29024195671081543
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 82.6
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 22.70186972618103
# Memory Searching % used: 58712247
# CPU Searching % used: 96.6
# Accuracy: 0.3533950617283951
# MCC: 0.34037780295187087
# Sensitivity: 0.9285714285714286
# Specificity: 0.937007874015748
# Time training Kmeans: 170.8520348072052
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.2601945400238037
# Memory searching Kmeans % used: 58713144
# CPU searching Kmeans % used: 78.9
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 33.60962796211243
# Memory Searching % used: 58712247
# CPU Searching % used: 97.2
# Accuracy: 0.3534652076318743
# MCC: 0.340449597368863
# Sensitivity: 0.9285714285714286
# Specificity: 0.937007874015748
# Time training Kmeans: 171.8403193950653
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.27030372619628906
# Memory searching Kmeans % used: 58713144
# CPU searching Kmeans % used: 83.9
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 45.05609750747681
# Memory Searching % used: 58712247
# CPU Searching % used: 97.7
# Accuracy: 0.3534652076318743
# MCC: 0.340449597368863
# Sensitivity: 0.9285714285714286
# Specificity: 0.937007874015748
# Time training Kmeans: 172.0337245464325
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.9
# Time searching Kmeans: 0.3203115463256836
# Memory searching Kmeans % used: 58713144
# CPU searching Kmeans % used: 87.5
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching:
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 1.301041603088379
# Memory Searching % used: 58712247
# CPU Searching % used: 88.2
# Accuracy: 0.21029741863075196
# MCC: 0.19405154679630315
# Sensitivity: 0.71875
# Specificity: 0.8554216867469879
# Time training Kmeans: 183.05971145629883
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.6
# Time searching Kmeans: 0.28012609481811523
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 82.7
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 1.0507071018218994
# Memory Searching % used: 58712247
# CPU Searching % used: 86.1
# Accuracy: 0.21029741863075196
# MCC: 0.19405154679630315
# Sensitivity: 0.71875
# Specificity: 0.8554216867469879
# Time training Kmeans: 183.2514419555664
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.3401787281036377
# Memory searching Kmeans % used: 58713144
# CPU searching Kmeans % used: 82.2
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 1.2210371494293213
# Memory Searching % used: 58712247
# CPU Searching % used: 88.6
# Accuracy: 0.21029741863075196
# MCC: 0.19405154679630315
# Sensitivity: 0.71875
# Specificity: 0.8554216867469879
# Time training Kmeans: 181.79714059829712
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.2802095413208008
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 82.9
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 1.090989112854004
# Memory Searching % used: 58712247
# CPU Searching % used: 86.4
# Accuracy: 0.21029741863075196
# MCC: 0.19405154679630315
# Sensitivity: 0.71875
# Specificity: 0.8554216867469879
# Time training Kmeans: 183.41642880439758
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.8
# Time searching Kmeans: 0.3803527355194092
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 86.7
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 1.3016061782836914
# Memory Searching % used: 58711927
# CPU Searching % used: 88.8
# Accuracy: 0.21029741863075196
# MCC: 0.19405154679630315
# Sensitivity: 0.71875
# Specificity: 0.8554216867469879
# Time training Kmeans: 182.99846506118774
# Memory training Kmeans % used: 682718333
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.28037571907043457
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 81.0
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 1.061046838760376
# Memory Searching % used: 58712247
# CPU Searching % used: 89.4
# Accuracy: 0.21029741863075196
# MCC: 0.19405154679630315
# Sensitivity: 0.71875
# Specificity: 0.8554216867469879
# Time training Kmeans: 183.9111728668213
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.30023908615112305
# Memory searching Kmeans % used: 58713144
# CPU searching Kmeans % used: 81.1
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 1.0809950828552246
# Memory Searching % used: 58712247
# CPU Searching % used: 87.2
# Accuracy: 0.21029741863075196
# MCC: 0.19405154679630315
# Sensitivity: 0.71875
# Specificity: 0.8554216867469879
# Time training Kmeans: 181.35692048072815
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.26216578483581543
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 75.5
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615
# Time Searching: 1.0408082008361816
# Memory Searching % used: 58712247
# CPU Searching % used: 86.1
# Accuracy: 0.21029741863075196
# MCC: 0.19405154679630315
# Sensitivity: 0.71875
# Specificity: 0.8554216867469879
# Time training Kmeans: 181.05698204040527
# Memory training Kmeans % used: 682718388
# CPU training Kmeans % used: 98.7
# Time searching Kmeans: 0.34029364585876465
# Memory searching Kmeans % used: 58713145
# CPU searching Kmeans % used: 82.8
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
#
# 165615

# %%
import os
import pandas as pd

# Set the path to the folder containing CSV files
folder_path = './csv'

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Initialize an empty DataFrame to store concatenated data
concatenated_df = pd.DataFrame()

# Loop through each CSV file and concatenate it to the DataFrame
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    concatenated_df = pd.concat([concatenated_df, df], ignore_index=True)

# Specify the path for the output concatenated CSV file
output_csv_path = 'concatenated_parameter_faiss.csv'

# Save the concatenated DataFrame to a CSV file
concatenated_df.to_csv(output_csv_path, index=False)

print(f"Concatenation complete. Results saved to: {output_csv_path}")
# Out:
# Concatenation complete. Results saved to: concatenated_parameter_faiss.csv

# %% [markdown]
# Generate Distance Matrix for UMAP

# %%
import time
import faiss
import psutil
import os
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef, homogeneity_completeness_v_measure
import pandas as pd

#Generate the index using FlatL2. Returns Euclidean Distances. May want to run parameters again to verify
nlist = 4096
index = faiss.index_factory(num_features, 'PCAW64,Flat')
index.train(embedding_db)
index.add(embedding_db)

# %%
#Search Index to generate index and distance vectors. Check if doing this correctly (verify dimensions and if we're missing a step)
D_p, I_p = index.search(embedding_t, len(embedding_db))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-22-127f09201799> in <module>
#       1 #Search Index to generate index and distance vectors. Check if doing this correctly (verify dimensions and if we're missing a step)
# ----> 2 D_p, I_p = index.search(embedding_t, len(embedding_db))
#
# ~\anaconda1\lib\site-packages\faiss\class_wrappers.py in replacement_search(self, x, k, params, D, I)
#     337
#     338         if I is None:
# --> 339             I = np.empty((n, k), dtype=np.int64)
#     340         else:
#     341             assert I.shape == (n, k)
#
# MemoryError: Unable to allocate 17.6 GiB for an array with shape (14256, 165615) and data type int64

# %%
print(f'Distance Dimensions: {D_p.shape}')
print(f'Index Dimensions: {I_p.shape}')
# Out:
# Distance Dimensions: (14256, 165615)
# Index Dimensions: (14256, 165615)

# %%
np.save('faiss_embeddings_distance_matrix.npy', D_p)
np.save('faiss_embeddings_index_matrix.npy', I_p)

# %%
ncentroids = 1024
niter = 60
verbose = True
kmeans = faiss.Kmeans(num_features, ncentroids, niter=niter, verbose=verbose)
kmeans.train(embedding_db)
D, I = kmeans.index.search(embedding_t, 1)
predicted_label_cluster_phylum = X_train.iloc[I.reshape(-1)]["phylum"]  # Verify
h_phylum, c_phylum, v_phylum = homogeneity_completeness_v_measure(X_test["phylum"], predicted_label_cluster_phylum)
predicted_label_cluster_genus = X_train.iloc[I.reshape(-1)]["genus"]  # Verify
h_genus, c_genus, v_genus = homogeneity_completeness_v_measure(X_test["genus"], predicted_label_cluster_genus)


print(f'Homogeneity Phylum: {h_phylum}')
print(f'Completeness Phylum: {c_phylum}')
print(f'V-Measure Phylum: {v_phylum}')
print()
print(f'Homogeneity Genus: {h_genus}')
print(f'Completeness Genus: {c_genus}')
print(f'V-Measure Genus: {v_genus}')
# Out:
# Homogeneity Phylum: 0.027160462493759557
# Completeness Phylum: 0.0416747453773972
# V-Measure Phylum: 0.03288739567340118
#
# Homogeneity Genus: 0.6019077534681689
# Completeness Genus: 0.5864351184743993
# V-Measure Genus: 0.5940707064430887
